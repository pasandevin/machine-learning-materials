# %% [markdown]
# # Our Problem
#
# Training, Evaluating and Testing a Machine Learning Algorithm to Identify Sinhala Handwritten Characters.
#
# ## 1. Identifying Features and Labels
#
# ![gray.png](attachment:gray.png)
# ![colors.png](attachment:colors.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data and Target
# ![Features%20Target.png](attachment:Features%20Target.png)

# %% [markdown]
# ## Image Flattening
# ![flatten.png](attachment:flatten.png)

# %% [markdown]
# # Train Test Split
# ![train%20test.png](attachment:train%20test.png)

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.2)

# %% [markdown]
# # Training the KNN Algorithm
# ![3.png](attachment:3.png)

# %% [markdown]
# # Evaluating the Algorithm
# ![9.png](attachment:9.png)

# %% [markdown]
# # Read Time Predictions
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # K Nearest Neighbor Algorithm (Classifier)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Training
#
# ![KNN.png](attachment:KNN.png)
#
#
# ## Predicting
#
# ![KNN1.png](attachment:KNN1.png)
#
# ### How to Measure the Distance
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Euclidean Distance How to deal when there are more than 2 Features
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Euclidean Disance Example
#
# ![Picture2.png](attachment:Picture2.png)

# %% [markdown]
# ## What is K?
#
# ![KNN2.png](attachment:KNN2.png)
#
# ## KNN Algorithm Summary
# ![Picture1.png](attachment:Picture1.png)
